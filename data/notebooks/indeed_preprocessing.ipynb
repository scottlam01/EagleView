# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in all data from indeed job postings 2023-2024
DATA_PATH = "../data/raw/indeed_2023-2024/"

companies = pd.read_csv(DATA_PATH + "companies.csv")
companies_employee_counts = pd.read_csv(DATA_PATH + "companies_employee_counts.csv")
companies_industries = pd.read_csv(DATA_PATH + "companies_industries.csv")
companies_specialities = pd.read_csv(DATA_PATH + "companies_specialities.csv")
job_benefits = pd.read_csv(DATA_PATH + "job_benefits.csv")
job_industries = pd.read_csv(DATA_PATH + "job_industries.csv")
job_salaries = pd.read_csv(DATA_PATH + "job_salaries.csv")
job_skills = pd.read_csv(DATA_PATH + "job_skills.csv")
mappings_industries = pd.read_csv(DATA_PATH + "mappings_industries.csv")
mappings_skills = pd.read_csv(DATA_PATH + "mappings_skills.csv")
postings = pd.read_csv(DATA_PATH + "postings.csv")

# %% [markdown]
# # Creating Dataset for Mapping

# %% [markdown]
# ## Filtering for Mapping
# - if null **zip_code** then use location to create lat/long by mapping
# - if location isn't in "city, state" format, then finally drop
# ## Deletes
# - delete row if **company_id** and **company_name** both null
# - delete columns (*applies, original_listed_time, application_url, application_type, expiry, closed_time, listed_time*)
# ## Updates
# - rename **company_name** to "Unknown Company" if **company_name** is null
# - use pd.to_datetime() to convert *original_listed_time, closed_time, listed_time* to datetime objects

# %% [markdown]
# ---
# ## Notes
# - A lot of salary data not present

# %% [markdown]
# Total rows in postings: 123849

# %% [markdown]
# ---
# ## Data exploring

# %% [markdown]
# - Checking missing values, and empty strings

# %%
# Count missing values
print(postings.isna().sum())

# Check empty strings specifically
print((postings == '').sum())
# Out:
# job_id                             0
# company_name                    1719
# title                              0
# description                        7
# max_salary                     94056
# pay_period                     87776
# location                           0
# company_id                      1717
# views                           1689
# med_salary                    117569
# min_salary                     94056
# formatted_work_type                0
# applies                       100529
# original_listed_time               0
# remote_allowed                108603
# job_posting_url                    0
# application_url                36665
# application_type                   0
# expiry                             0
# closed_time                   122776
# formatted_experience_level     29409
# skills_desc                   121410
# listed_time                        0
# posting_domain                 39968
# sponsored                          0
# ...

# %%
postings.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 123849 entries, 0 to 123848
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   job_id                      123849 non-null  int64
#  1   company_name                122130 non-null  str
#  2   title                       123849 non-null  str
#  3   description                 123842 non-null  str
#  4   max_salary                  29793 non-null   float64
#  5   pay_period                  36073 non-null   str
#  6   location                    123849 non-null  str
#  7   company_id                  122132 non-null  float64
#  8   views                       122160 non-null  float64
#  9   med_salary                  6280 non-null    float64
#  10  min_salary                  29793 non-null   float64
#  11  formatted_work_type         123849 non-null  str
#  12  applies                     23320 non-null   float64
# ...

# %%
postings.head().to_csv("../data/processed/temp.csv", index=False)

# %%
postings["views"].unique()
# Out:
# np.float64(nan)
